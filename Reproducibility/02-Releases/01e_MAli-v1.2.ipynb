# %% [markdown]
# ## Release Testing: MAli-v1.2 on BALIS-2

# %% [markdown]
# #### Imports

# %%
import os
import shutil
import subprocess
import time
import pandas as pd

# %%
from wrapped_scorer import WrappedScorer

# %% [markdown]
# #### MAli

# %%
SEED = 9032025

# %%
ALIGNER_NAME = "MAli-v1.2"
ALIGNER_PATH = f"aligners/{ALIGNER_NAME}/MAli.exe"
OUTPUT_FOLDER = f"aligners/{ALIGNER_NAME}/output"

# %%
# creating empty output folder
if os.path.exists(OUTPUT_FOLDER):
    shutil.rmtree(OUTPUT_FOLDER)
os.makedirs(OUTPUT_FOLDER)

# %%
RESULTS_FILE_DIRECTORY = f"results/{ALIGNER_NAME}"

# %%
# creating empty output folder
if os.path.exists(RESULTS_FILE_DIRECTORY):
    shutil.rmtree(RESULTS_FILE_DIRECTORY)
os.makedirs(RESULTS_FILE_DIRECTORY)

# %% [markdown]
# #### BALIS-2

# %%
DATASET_NAME = "BALIS-2"
DATASET_FOLDER = f"datasets/{DATASET_NAME}"
INPUT_FOLDER = f"{DATASET_FOLDER}/in"
REFERENCES_FOLDER = f"{DATASET_FOLDER}/ref"

# %%
# checking that testcases have been found
testcases = os.listdir(INPUT_FOLDER)
print(testcases[:10])
# Out:
# ['BB11001', 'BB11002', 'BB11003', 'BB11006', 'BB11007', 'BB11010', 'BB11012', 'BB11013', 'BB11017', 'BB11020']

# %% [markdown]
# #### QScore

# %%
SCORER_PATH = "scorers/QScore/qscore.exe"

# %%
scorer = WrappedScorer(SCORER_PATH)

# %% [markdown]
# #### Performing Alignment

# %%
def perform_alignment_and_record_time(filename):

    input_path = f"{INPUT_FOLDER}/{filename}"
    output_path = f"{OUTPUT_FOLDER}/{filename}"
    command = f"{ALIGNER_PATH} -input {input_path} -output {output_path} -seed {SEED} -iterations {iterations}"

    start_time = time.perf_counter()
    
    subprocess.run(command)

    end_time = time.perf_counter()
    
    time_in_milliseconds = (end_time - start_time) * 1000
    time_in_milliseconds = round(time_in_milliseconds, 0)

    return int(time_in_milliseconds)

# %%
def score_quality_of_produced_alignment(filename):

    test_path = f"{OUTPUT_FOLDER}/{filename}.faa"
    reference_path = f"{REFERENCES_FOLDER}/{filename}"
    score = scorer.score_testcase(test_path, reference_path)

    return score

# %%
def record_performance_on_testcase(filename):

    time_taken = perform_alignment_and_record_time(testcase)
    score = score_quality_of_produced_alignment(testcase)


    return f"{ALIGNER_NAME},{DATASET_NAME},{filename},{score},{time_taken}"

# %%
def write_records_to_csv(records, filename):

    RESULTS_FILEPATH = f"{RESULTS_FILE_DIRECTORY}/{filename}"

    with open(RESULTS_FILEPATH, "w") as file:
        for record in RECORDS:
            file.write(record)
            file.write("\n")

    print(f"Results written to: {RESULTS_FILEPATH}")

# %%
HEADER = "aligner,dataset,testcase,Q_score,time_elapsed_ms"

# %%
for iterations in [2500, 1000, 500, 200, 100, 1]:
    RECORDS = []
    RECORDS.append(HEADER)

    RESULTS_FILENAME = f"sbench_{ALIGNER_NAME}_on_{DATASET_NAME}_{iterations}_iterations.csv"
    RESULTS_FILEPATH = f"results/{RESULTS_FILENAME}"
    for testcase in testcases:
        record = record_performance_on_testcase(testcase)
        print(record)
        RECORDS.append(record)

    write_records_to_csv(RECORDS, RESULTS_FILENAME)
# Out:
# MAli-v1.2,BALIS-2,BB11001,0.816,1730
# MAli-v1.2,BALIS-2,BB11002,0.214,3104
# MAli-v1.2,BALIS-2,BB11003,0.183,8204
# MAli-v1.2,BALIS-2,BB11006,0.0699,4514
# MAli-v1.2,BALIS-2,BB11007,0.314,8398
# MAli-v1.2,BALIS-2,BB11010,0.0427,8222
# MAli-v1.2,BALIS-2,BB11012,0.556,6064
# MAli-v1.2,BALIS-2,BB11013,0.0517,1880
# MAli-v1.2,BALIS-2,BB11017,0.446,4287
# MAli-v1.2,BALIS-2,BB11020,0.241,4223
# MAli-v1.2,BALIS-2,BB11023,0.135,6049
# MAli-v1.2,BALIS-2,BB11024,0.0906,6773
# MAli-v1.2,BALIS-2,BB11026,0.143,11467
# MAli-v1.2,BALIS-2,BB11028,0.0856,3608
# MAli-v1.2,BALIS-2,BB11030,0.044,6442
# MAli-v1.2,BALIS-2,BB11032,0.117,6292
# MAli-v1.2,BALIS-2,BB11034,0.124,11203
# MAli-v1.2,BALIS-2,BB11035,0.232,2338
# MAli-v1.2,BALIS-2,BB11036,0.161,7058
# MAli-v1.2,BALIS-2,BB12001,0.667,7639
# MAli-v1.2,BALIS-2,BB12003,0.946,1351
# MAli-v1.2,BALIS-2,BB12006,0.886,3570
# MAli-v1.2,BALIS-2,BB12008,0.825,5790
# MAli-v1.2,BALIS-2,BB12015,0.483,3109
# MAli-v1.2,BALIS-2,BB12017,0.612,7692
# MAli-v1.2,BALIS-2,BB12020,0.848,2319
# MAli-v1.2,BALIS-2,BB12022,1.0,2494
# MAli-v1.2,BALIS-2,BB12025,0.849,3357
# MAli-v1.2,BALIS-2,BB12032,0.867,1480
# MAli-v1.2,BALIS-2,BB12033,0.553,6913
# MAli-v1.2,BALIS-2,BB12035,0.89,4249
# MAli-v1.2,BALIS-2,BB12036,0.686,3928
# MAli-v1.2,BALIS-2,BB12038,0.811,4048
# MAli-v1.2,BALIS-2,BB12041,0.635,2202
# MAli-v1.2,BALIS-2,BB12043,0.825,4178
# MAli-v1.2,BALIS-2,BB20002,0.129,3254
# MAli-v1.2,BALIS-2,BB20005,0.0648,7782
# MAli-v1.2,BALIS-2,BB20010,0.289,9515
# MAli-v1.2,BALIS-2,BB20016,0.513,5125
# MAli-v1.2,BALIS-2,BB20018,0.725,5440
# MAli-v1.2,BALIS-2,BB20019,0.0,10629
# MAli-v1.2,BALIS-2,BB20020,0.667,4539
# MAli-v1.2,BALIS-2,BB20025,0.156,6933
# MAli-v1.2,BALIS-2,BB20026,0.0,11775
# MAli-v1.2,BALIS-2,BB20028,0.65,8545
# MAli-v1.2,BALIS-2,BB20029,0.046,1838
# MAli-v1.2,BALIS-2,BB20030,0.0833,1840
# MAli-v1.2,BALIS-2,BB20031,0.0587,6123
# MAli-v1.2,BALIS-2,BB20032,0.412,1984
# MAli-v1.2,BALIS-2,BB20033,0.458,2128
# MAli-v1.2,BALIS-2,BB20034,0.149,6726
# MAli-v1.2,BALIS-2,BB12041,0.591,893
# MAli-v1.2,BALIS-2,BB12043,0.787,1403
# MAli-v1.2,BALIS-2,BB20002,0.0,1118
# MAli-v1.2,BALIS-2,BB20005,0.0164,2132
# MAli-v1.2,BALIS-2,BB20010,0.303,2545
# MAli-v1.2,BALIS-2,BB20016,0.263,1595
# MAli-v1.2,BALIS-2,BB20018,0.643,1669
# MAli-v1.2,BALIS-2,BB20019,0.004,2612
# MAli-v1.2,BALIS-2,BB20020,0.464,1466
# MAli-v1.2,BALIS-2,BB20025,0.156,1946
# MAli-v1.2,BALIS-2,BB20026,0.0,2887
# MAli-v1.2,BALIS-2,BB20028,0.444,2172
# MAli-v1.2,BALIS-2,BB20029,0.0287,811
# MAli-v1.2,BALIS-2,BB20030,0.141,785
# MAli-v1.2,BALIS-2,BB20031,0.0429,1753
# MAli-v1.2,BALIS-2,BB20032,0.461,851
# MAli-v1.2,BALIS-2,BB20033,0.41,924
# MAli-v1.2,BALIS-2,BB20034,0.0434,1773
# MAli-v1.2,BALIS-2,BB20035,0.148,1650
# MAli-v1.2,BALIS-2,BB20036,0.107,1276
# MAli-v1.2,BALIS-2,BB20037,0.0214,2999
# MAli-v1.2,BALIS-2,BB20038,0.257,927
# MAli-v1.2,BALIS-2,BB20039,0.0466,1911
# MAli-v1.2,BALIS-2,BB20040,0.448,2136
# MAli-v1.2,BALIS-2,BB30002,0.267,1947
# MAli-v1.2,BALIS-2,BB30003,0.0722,2141
# MAli-v1.2,BALIS-2,BB30005,0.522,2307
# MAli-v1.2,BALIS-2,BB30009,0.0,788
# MAli-v1.2,BALIS-2,BB30010,0.265,2451
# MAli-v1.2,BALIS-2,BB30012,0.342,1911
# MAli-v1.2,BALIS-2,BB30013,0.0322,2772
# MAli-v1.2,BALIS-2,BB30020,0.0667,1476
# MAli-v1.2,BALIS-2,BB30024,0.00571,1832
# MAli-v1.2,BALIS-2,BB30030,0.118,1853
# MAli-v1.2,BALIS-2,BB40002,0.549,1089
# MAli-v1.2,BALIS-2,BB40006,0.353,1838
# MAli-v1.2,BALIS-2,BB40011,0.318,1642
# MAli-v1.2,BALIS-2,BB40012,0.54,1587
# MAli-v1.2,BALIS-2,BB40013,0.446,1560
# MAli-v1.2,BALIS-2,BB40014,0.821,1477
# MAli-v1.2,BALIS-2,BB40017,0.246,1233
# MAli-v1.2,BALIS-2,BB40023,0.585,2411
# MAli-v1.2,BALIS-2,BB40030,0.546,1606
# MAli-v1.2,BALIS-2,BB40034,0.224,2949
# MAli-v1.2,BALIS-2,BB40035,0.935,1455
# MAli-v1.2,BALIS-2,BB40040,0.815,1277
# MAli-v1.2,BALIS-2,BB40042,0.263,1650
# MAli-v1.2,BALIS-2,BB40043,0.139,1812
# MAli-v1.2,BALIS-2,BB40044,0.4,1346
# MAli-v1.2,BALIS-2,BB40045,0.605,892
# MAli-v1.2,BALIS-2,BB50002,0.0134,2929
# MAli-v1.2,BALIS-2,BB50003,0.284,2364
# MAli-v1.2,BALIS-2,BB50006,0.02,3071
# MAli-v1.2,BALIS-2,BB50009,0.213,2220
# MAli-v1.2,BALIS-2,BB50010,0.16,1928
# MAli-v1.2,BALIS-2,BB50013,0.675,1390
# MAli-v1.2,BALIS-2,BB50015,0.0308,2269
# Results written to: results/MAli-v1.2/sbench_MAli-v1.2_on_BALIS-2_500_iterations.csv
# MAli-v1.2,BALIS-2,BB11001,0.81,458
# MAli-v1.2,BALIS-2,BB11002,0.0273,759
# MAli-v1.2,BALIS-2,BB11003,0.183,1171
# MAli-v1.2,BALIS-2,BB11006,0.0208,995
# MAli-v1.2,BALIS-2,BB11007,0.161,1207
# MAli-v1.2,BALIS-2,BB11010,0.0897,1230
# MAli-v1.2,BALIS-2,BB11012,0.53,964
# MAli-v1.2,BALIS-2,BB11013,0.0,502
# MAli-v1.2,BALIS-2,BB11017,0.405,866
# MAli-v1.2,BALIS-2,BB11020,0.0226,795
# MAli-v1.2,BALIS-2,BB11023,0.0685,1084
# MAli-v1.2,BALIS-2,BB11024,0.0372,1150
# MAli-v1.2,BALIS-2,BB11026,0.0623,1578
# MAli-v1.2,BALIS-2,BB11028,0.00778,832
# MAli-v1.2,BALIS-2,BB11030,0.0317,1134
# MAli-v1.2,BALIS-2,BB11032,0.0,1146
# MAli-v1.2,BALIS-2,BB11034,0.00929,1533
# MAli-v1.2,BALIS-2,BB11035,0.17,582
# MAli-v1.2,BALIS-2,BB11036,0.0761,1044
# MAli-v1.2,BALIS-2,BB12001,0.478,1159
# MAli-v1.2,BALIS-2,BB12003,0.964,278
# MAli-v1.2,BALIS-2,BB12006,0.836,767
# MAli-v1.2,BALIS-2,BB12008,0.782,1014
# MAli-v1.2,BALIS-2,BB12015,0.394,763
# MAli-v1.2,BALIS-2,BB12017,0.598,1179
# MAli-v1.2,BALIS-2,BB12020,0.829,615
# MAli-v1.2,BALIS-2,BB12022,0.327,666
# MAli-v1.2,BALIS-2,BB12025,0.859,774
# MAli-v1.2,BALIS-2,BB12032,0.889,334
# MAli-v1.2,BALIS-2,BB12033,0.412,1061
# MAli-v1.2,BALIS-2,BB12035,0.586,904
# MAli-v1.2,BALIS-2,BB12036,0.477,818
# MAli-v1.2,BALIS-2,BB12038,0.777,796
# MAli-v1.2,BALIS-2,BB12041,0.657,547
# MAli-v1.2,BALIS-2,BB12043,0.393,855
# MAli-v1.2,BALIS-2,BB20002,0.0,761
# MAli-v1.2,BALIS-2,BB20005,0.00795,1201
# MAli-v1.2,BALIS-2,BB20010,0.537,1323
# MAli-v1.2,BALIS-2,BB20016,0.333,980
# MAli-v1.2,BALIS-2,BB20018,0.417,1011
# MAli-v1.2,BALIS-2,BB20019,0.0213,1412
# MAli-v1.2,BALIS-2,BB20020,0.435,889
# MAli-v1.2,BALIS-2,BB20025,0.156,1072
# MAli-v1.2,BALIS-2,BB20026,0.0941,1606
# MAli-v1.2,BALIS-2,BB20028,0.482,1232
# MAli-v1.2,BALIS-2,BB20029,0.023,484
# MAli-v1.2,BALIS-2,BB20030,0.0,542
# MAli-v1.2,BALIS-2,BB20031,0.0698,1068
# MAli-v1.2,BALIS-2,BB20032,0.421,585
# MAli-v1.2,BALIS-2,BB20033,0.338,561
# MAli-v1.2,BALIS-2,BB20034,0.0111,1104
# MAli-v1.2,BALIS-2,BB20035,0.0619,1020
# MAli-v1.2,BALIS-2,BB20036,0.0444,821
# MAli-v1.2,BALIS-2,BB20037,0.0411,1485
# MAli-v1.2,BALIS-2,BB20038,0.238,571
# MAli-v1.2,BALIS-2,BB20039,0.0,1151
# MAli-v1.2,BALIS-2,BB20040,0.367,1175
# MAli-v1.2,BALIS-2,BB30002,0.334,1148
# MAli-v1.2,BALIS-2,BB30003,0.0163,1177
# MAli-v1.2,BALIS-2,BB30005,0.26,1168
# MAli-v1.2,BALIS-2,BB30009,0.0,459
# MAli-v1.2,BALIS-2,BB30010,0.265,1360
# MAli-v1.2,BALIS-2,BB30012,0.381,1089
# MAli-v1.2,BALIS-2,BB30013,0.0191,1429
# MAli-v1.2,BALIS-2,BB30020,0.00238,910
# MAli-v1.2,BALIS-2,BB30024,0.0429,1091
# MAli-v1.2,BALIS-2,BB30030,0.101,1137
# MAli-v1.2,BALIS-2,BB40002,0.494,744
# MAli-v1.2,BALIS-2,BB40006,0.283,1117
# MAli-v1.2,BALIS-2,BB40011,0.0713,1045
# MAli-v1.2,BALIS-2,BB40012,0.279,954
# MAli-v1.2,BALIS-2,BB40013,0.101,971
# MAli-v1.2,BALIS-2,BB40014,0.802,884
# MAli-v1.2,BALIS-2,BB40017,0.324,906
# MAli-v1.2,BALIS-2,BB40023,0.542,1341
# MAli-v1.2,BALIS-2,BB40030,0.556,962
# MAli-v1.2,BALIS-2,BB40034,0.224,1592
# MAli-v1.2,BALIS-2,BB40035,0.935,865
# MAli-v1.2,BALIS-2,BB40040,0.782,816
# MAli-v1.2,BALIS-2,BB40042,0.151,1004
# MAli-v1.2,BALIS-2,BB40043,0.055,1121
# MAli-v1.2,BALIS-2,BB40044,0.0827,814
# MAli-v1.2,BALIS-2,BB40045,0.668,507
# MAli-v1.2,BALIS-2,BB50002,0.0174,1594
# MAli-v1.2,BALIS-2,BB50003,0.297,1273
# MAli-v1.2,BALIS-2,BB50006,0.031,1599
# MAli-v1.2,BALIS-2,BB50009,0.111,1285
# MAli-v1.2,BALIS-2,BB50010,0.19,1153
# MAli-v1.2,BALIS-2,BB50013,0.672,850
# MAli-v1.2,BALIS-2,BB50015,0.0289,1411
# Results written to: results/MAli-v1.2/sbench_MAli-v1.2_on_BALIS-2_200_iterations.csv
# MAli-v1.2,BALIS-2,BB11001,0.494,228
# MAli-v1.2,BALIS-2,BB11002,0.0,556
# MAli-v1.2,BALIS-2,BB11003,0.118,879
# MAli-v1.2,BALIS-2,BB11006,0.0283,680
# MAli-v1.2,BALIS-2,BB11007,0.0771,894
# MAli-v1.2,BALIS-2,BB11010,0.047,887
# MAli-v1.2,BALIS-2,BB11012,0.444,792
# MAli-v1.2,BALIS-2,BB11013,0.0448,229
# MAli-v1.2,BALIS-2,BB11017,0.374,666
# MAli-v1.2,BALIS-2,BB11020,0.0411,596
# MAli-v1.2,BALIS-2,BB11023,0.0552,765
# MAli-v1.2,BALIS-2,BB11024,0.0,837
# MAli-v1.2,BALIS-2,BB11026,0.0183,1087
# MAli-v1.2,BALIS-2,BB11028,0.04,652
# MAli-v1.2,BALIS-2,BB11030,0.00828,853
# MAli-v1.2,BALIS-2,BB11032,0.00846,780
# MAli-v1.2,BALIS-2,BB11034,0.00714,1034
# MAli-v1.2,BALIS-2,BB11035,0.184,324
# MAli-v1.2,BALIS-2,BB11036,0.0342,864
# MAli-v1.2,BALIS-2,BB12001,0.478,811
# MAli-v1.2,BALIS-2,BB12003,0.82,171
# MAli-v1.2,BALIS-2,BB12006,0.799,577
# MAli-v1.2,BALIS-2,BB12008,0.475,726
# MAli-v1.2,BALIS-2,BB12015,0.169,587
# MAli-v1.2,BALIS-2,BB12017,0.519,819
# MAli-v1.2,BALIS-2,BB12020,0.807,305
# MAli-v1.2,BALIS-2,BB12022,0.327,342
# MAli-v1.2,BALIS-2,BB12025,0.849,543
# MAli-v1.2,BALIS-2,BB12032,0.504,193
# MAli-v1.2,BALIS-2,BB12033,0.412,795
# MAli-v1.2,BALIS-2,BB12035,0.714,709
# MAli-v1.2,BALIS-2,BB12036,0.207,640
# MAli-v1.2,BALIS-2,BB12038,0.427,654
# MAli-v1.2,BALIS-2,BB12041,0.433,243
# MAli-v1.2,BALIS-2,BB12043,0.309,524
# MAli-v1.2,BALIS-2,BB20002,0.0753,508
# MAli-v1.2,BALIS-2,BB20005,0.0241,838
# MAli-v1.2,BALIS-2,BB20010,0.539,975
# MAli-v1.2,BALIS-2,BB20016,0.0635,806
# MAli-v1.2,BALIS-2,BB20018,0.224,745
# MAli-v1.2,BALIS-2,BB20019,0.0,938
# MAli-v1.2,BALIS-2,BB20020,0.25,718
# MAli-v1.2,BALIS-2,BB20025,0.156,780
# MAli-v1.2,BALIS-2,BB20026,0.0,1065
# MAli-v1.2,BALIS-2,BB20028,0.296,830
# MAli-v1.2,BALIS-2,BB20029,0.0,218
# MAli-v1.2,BALIS-2,BB20030,0.0729,226
# MAli-v1.2,BALIS-2,BB20031,0.0556,762
# MAli-v1.2,BALIS-2,BB20032,0.206,241
# MAli-v1.2,BALIS-2,BB20033,0.32,314
# MAli-v1.2,BALIS-2,BB20034,0.0115,864
# MAli-v1.2,BALIS-2,BB20035,0.0333,749
# MAli-v1.2,BALIS-2,BB20036,0.0444,397
# MAli-v1.2,BALIS-2,BB20037,0.00952,1022
# MAli-v1.2,BALIS-2,BB20038,0.257,261
# MAli-v1.2,BALIS-2,BB20039,0.0184,848
# MAli-v1.2,BALIS-2,BB20040,0.384,829
# MAli-v1.2,BALIS-2,BB30002,0.236,866
# MAli-v1.2,BALIS-2,BB30003,0.0278,841
# MAli-v1.2,BALIS-2,BB30005,0.049,912
# MAli-v1.2,BALIS-2,BB30009,0.0,212
# MAli-v1.2,BALIS-2,BB30010,0.355,907
# MAli-v1.2,BALIS-2,BB30012,0.328,893
# MAli-v1.2,BALIS-2,BB30013,0.0,1066
# MAli-v1.2,BALIS-2,BB30020,0.0,732
# MAli-v1.2,BALIS-2,BB30024,0.0181,814
# MAli-v1.2,BALIS-2,BB30030,0.108,860
# MAli-v1.2,BALIS-2,BB40002,0.0727,520
# MAli-v1.2,BALIS-2,BB40006,0.3,738
# MAli-v1.2,BALIS-2,BB40011,0.0319,730
# MAli-v1.2,BALIS-2,BB40012,0.44,743
# MAli-v1.2,BALIS-2,BB40013,0.0714,741
# MAli-v1.2,BALIS-2,BB40014,0.821,712
# MAli-v1.2,BALIS-2,BB40017,0.182,556
# MAli-v1.2,BALIS-2,BB40023,0.313,850
# MAli-v1.2,BALIS-2,BB40030,0.476,776
# MAli-v1.2,BALIS-2,BB40034,0.224,1071
# MAli-v1.2,BALIS-2,BB40035,0.935,677
# MAli-v1.2,BALIS-2,BB40040,0.425,621
# MAli-v1.2,BALIS-2,BB40042,0.0626,702
# MAli-v1.2,BALIS-2,BB40043,0.0563,748
# MAli-v1.2,BALIS-2,BB40044,0.0827,544
# MAli-v1.2,BALIS-2,BB40045,0.411,275
# MAli-v1.2,BALIS-2,BB50002,0.00122,1072
# MAli-v1.2,BALIS-2,BB50003,0.297,917
# MAli-v1.2,BALIS-2,BB50006,0.00853,1091
# MAli-v1.2,BALIS-2,BB50009,0.141,919
# MAli-v1.2,BALIS-2,BB50010,0.19,883
# MAli-v1.2,BALIS-2,BB50013,0.664,701
# MAli-v1.2,BALIS-2,BB50015,0.008,911
# Results written to: results/MAli-v1.2/sbench_MAli-v1.2_on_BALIS-2_100_iterations.csv
# MAli-v1.2,BALIS-2,BB11001,0.0819,67
# MAli-v1.2,BALIS-2,BB11002,0.0126,74
# MAli-v1.2,BALIS-2,BB11003,0.0148,80
# MAli-v1.2,BALIS-2,BB11006,0.0104,73
# MAli-v1.2,BALIS-2,BB11007,0.0575,85
# MAli-v1.2,BALIS-2,BB11010,0.0,80
# MAli-v1.2,BALIS-2,BB11012,0.00598,77
# MAli-v1.2,BALIS-2,BB11013,0.0,72
# MAli-v1.2,BALIS-2,BB11017,0.115,76
# MAli-v1.2,BALIS-2,BB11020,0.033,72
# MAli-v1.2,BALIS-2,BB11023,0.0215,80
# MAli-v1.2,BALIS-2,BB11024,0.0,77
# MAli-v1.2,BALIS-2,BB11026,0.0,94
# MAli-v1.2,BALIS-2,BB11028,0.0211,76
# MAli-v1.2,BALIS-2,BB11030,0.0166,77
# MAli-v1.2,BALIS-2,BB11032,0.023,81
# MAli-v1.2,BALIS-2,BB11034,0.00821,81
# MAli-v1.2,BALIS-2,BB11035,0.027,72
# MAli-v1.2,BALIS-2,BB11036,0.0194,83
# MAli-v1.2,BALIS-2,BB12001,0.258,87
# MAli-v1.2,BALIS-2,BB12003,0.198,74
# MAli-v1.2,BALIS-2,BB12006,0.11,69
# MAli-v1.2,BALIS-2,BB12008,0.104,79
# MAli-v1.2,BALIS-2,BB12015,0.025,68
# MAli-v1.2,BALIS-2,BB12017,0.084,88
# MAli-v1.2,BALIS-2,BB12020,0.159,68
# MAli-v1.2,BALIS-2,BB12022,0.0327,67
# MAli-v1.2,BALIS-2,BB12025,0.224,78
# MAli-v1.2,BALIS-2,BB12032,0.248,71
# MAli-v1.2,BALIS-2,BB12033,0.0104,74
# MAli-v1.2,BALIS-2,BB12035,0.0819,70
# MAli-v1.2,BALIS-2,BB12036,0.0426,76
# MAli-v1.2,BALIS-2,BB12038,0.14,75
# MAli-v1.2,BALIS-2,BB12041,0.0804,71
# MAli-v1.2,BALIS-2,BB12043,0.0923,70
# MAli-v1.2,BALIS-2,BB20002,0.0,73
# MAli-v1.2,BALIS-2,BB20005,0.0194,79
# MAli-v1.2,BALIS-2,BB20010,0.0463,81
# MAli-v1.2,BALIS-2,BB20016,0.019,73
# MAli-v1.2,BALIS-2,BB20018,0.037,71
# MAli-v1.2,BALIS-2,BB20019,0.0133,91
# MAli-v1.2,BALIS-2,BB20020,0.0502,74
# MAli-v1.2,BALIS-2,BB20025,0.0,91
# MAli-v1.2,BALIS-2,BB20026,0.0,83
# MAli-v1.2,BALIS-2,BB20028,0.00386,82
# MAli-v1.2,BALIS-2,BB20029,0.0115,64
# MAli-v1.2,BALIS-2,BB20030,0.0833,69
# MAli-v1.2,BALIS-2,BB20031,0.0111,75
# MAli-v1.2,BALIS-2,BB20032,0.0848,69
# MAli-v1.2,BALIS-2,BB20033,0.185,72
# MAli-v1.2,BALIS-2,BB20034,0.0417,80
# MAli-v1.2,BALIS-2,BB20035,0.0467,79
# MAli-v1.2,BALIS-2,BB20036,0.0037,78
# MAli-v1.2,BALIS-2,BB20037,0.00595,90
# MAli-v1.2,BALIS-2,BB20038,0.00952,67
# MAli-v1.2,BALIS-2,BB20039,0.00485,78
# MAli-v1.2,BALIS-2,BB20040,0.034,81
# MAli-v1.2,BALIS-2,BB30002,0.00646,82
# MAli-v1.2,BALIS-2,BB30003,0.0103,82
# MAli-v1.2,BALIS-2,BB30005,0.0729,84
# MAli-v1.2,BALIS-2,BB30009,0.0494,66
# MAli-v1.2,BALIS-2,BB30010,0.0216,85
# MAli-v1.2,BALIS-2,BB30012,0.0429,75
# MAli-v1.2,BALIS-2,BB30013,0.0,87
# MAli-v1.2,BALIS-2,BB30020,0.00476,78
# MAli-v1.2,BALIS-2,BB30024,0.0019,81
# MAli-v1.2,BALIS-2,BB30030,0.0174,82
# MAli-v1.2,BALIS-2,BB40002,0.01,69
# MAli-v1.2,BALIS-2,BB40006,0.0444,78
# MAli-v1.2,BALIS-2,BB40011,0.0344,81
# MAli-v1.2,BALIS-2,BB40012,0.0177,82
# MAli-v1.2,BALIS-2,BB40013,0.04,71
# MAli-v1.2,BALIS-2,BB40014,0.0928,77
# MAli-v1.2,BALIS-2,BB40017,0.0565,74
# MAli-v1.2,BALIS-2,BB40023,0.0721,91
# MAli-v1.2,BALIS-2,BB40030,0.0171,76
# MAli-v1.2,BALIS-2,BB40034,0.0,88
# MAli-v1.2,BALIS-2,BB40035,0.0753,79
# MAli-v1.2,BALIS-2,BB40040,0.119,69
# MAli-v1.2,BALIS-2,BB40042,0.026,75
# MAli-v1.2,BALIS-2,BB40043,0.005,81
# MAli-v1.2,BALIS-2,BB40044,0.0107,70
# MAli-v1.2,BALIS-2,BB40045,0.0842,69
# MAli-v1.2,BALIS-2,BB50002,0.00824,93
# MAli-v1.2,BALIS-2,BB50003,0.066,83
# MAli-v1.2,BALIS-2,BB50006,0.00292,85
# MAli-v1.2,BALIS-2,BB50009,0.004,75
# MAli-v1.2,BALIS-2,BB50010,0.0,75
# MAli-v1.2,BALIS-2,BB50013,0.0,76
# MAli-v1.2,BALIS-2,BB50015,0.00739,82
# Results written to: results/MAli-v1.2/sbench_MAli-v1.2_on_BALIS-2_1_iterations.csv
