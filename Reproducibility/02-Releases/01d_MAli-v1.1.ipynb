# %% [markdown]
# ## Release Testing: MAli-v1.1 on BALIS-2

# %% [markdown]
# #### Imports

# %%
import os
import shutil
import subprocess
import time
import pandas as pd

# %%
from wrapped_scorer import WrappedScorer

# %% [markdown]
# #### MAli

# %%
SEED = 9032025

# %%
ALIGNER_NAME = "MAli-v1.1"
ALIGNER_PATH = f"aligners/{ALIGNER_NAME}/MAli.exe"
OUTPUT_FOLDER = f"aligners/{ALIGNER_NAME}/output"

# %%
# creating empty output folder
if os.path.exists(OUTPUT_FOLDER):
    shutil.rmtree(OUTPUT_FOLDER)
os.makedirs(OUTPUT_FOLDER)

# %%
RESULTS_FILE_DIRECTORY = f"results/{ALIGNER_NAME}"

# %%
# creating empty output folder
if os.path.exists(RESULTS_FILE_DIRECTORY):
    shutil.rmtree(RESULTS_FILE_DIRECTORY)
os.makedirs(RESULTS_FILE_DIRECTORY)

# %% [markdown]
# #### BALIS-2

# %%
DATASET_NAME = "BALIS-2"
DATASET_FOLDER = f"datasets/{DATASET_NAME}"
INPUT_FOLDER = f"{DATASET_FOLDER}/in"
REFERENCES_FOLDER = f"{DATASET_FOLDER}/ref"

# %%
# checking that testcases have been found
testcases = os.listdir(INPUT_FOLDER)
print(testcases[:10])
# Out:
# ['BB11001', 'BB11002', 'BB11003', 'BB11006', 'BB11007', 'BB11010', 'BB11012', 'BB11013', 'BB11017', 'BB11020']

# %% [markdown]
# #### QScore

# %%
SCORER_PATH = "scorers/QScore/qscore.exe"

# %%
scorer = WrappedScorer(SCORER_PATH)

# %% [markdown]
# #### Performing Alignment

# %%
def perform_alignment_and_record_time(filename):

    input_path = f"{INPUT_FOLDER}/{filename}"
    output_path = f"{OUTPUT_FOLDER}/{filename}"
    command = f"{ALIGNER_PATH} -input {input_path} -output {output_path} -seed {SEED} -iterations {iterations}"

    start_time = time.perf_counter()
    
    subprocess.run(command)

    end_time = time.perf_counter()
    
    time_in_milliseconds = (end_time - start_time) * 1000
    time_in_milliseconds = round(time_in_milliseconds, 0)

    return int(time_in_milliseconds)

# %%
def score_quality_of_produced_alignment(filename):

    test_path = f"{OUTPUT_FOLDER}/{filename}.faa"
    reference_path = f"{REFERENCES_FOLDER}/{filename}"
    score = scorer.score_testcase(test_path, reference_path)

    return score

# %%
def record_performance_on_testcase(filename):

    time_taken = perform_alignment_and_record_time(testcase)
    score = score_quality_of_produced_alignment(testcase)


    return f"{ALIGNER_NAME},{DATASET_NAME},{filename},{score},{time_taken}"

# %%
def write_records_to_csv(records, filename):

    RESULTS_FILEPATH = f"{RESULTS_FILE_DIRECTORY}/{filename}"

    with open(RESULTS_FILEPATH, "w") as file:
        for record in RECORDS:
            file.write(record)
            file.write("\n")

    print(f"Results written to: {RESULTS_FILEPATH}")

# %%
HEADER = "aligner,dataset,testcase,Q_score,time_elapsed_ms"

# %%
for iterations in [50, 40, 30, 20, 10, 1]:
    RECORDS = []
    RECORDS.append(HEADER)

    RESULTS_FILENAME = f"sbench_{ALIGNER_NAME}_on_{DATASET_NAME}_{iterations}_iterations.csv"
    RESULTS_FILEPATH = f"results/{RESULTS_FILENAME}"
    for testcase in testcases:
        record = record_performance_on_testcase(testcase)
# MAli-v1.1,BALIS-2,BB20002,0.0,2457
# MAli-v1.1,BALIS-2,BB20005,0.0187,5679
# MAli-v1.1,BALIS-2,BB20010,0.39,6355
# MAli-v1.1,BALIS-2,BB20016,0.0667,4096
# MAli-v1.1,BALIS-2,BB20018,0.283,3702
# MAli-v1.1,BALIS-2,BB20019,0.0,7371
# MAli-v1.1,BALIS-2,BB20020,0.22,3179
# MAli-v1.1,BALIS-2,BB20025,0.0,4607
# MAli-v1.1,BALIS-2,BB20026,0.0,7837
# MAli-v1.1,BALIS-2,BB20028,0.0367,5672
# MAli-v1.1,BALIS-2,BB20029,0.0,1625
# MAli-v1.1,BALIS-2,BB20030,0.0729,1593
# MAli-v1.1,BALIS-2,BB20031,0.0,4668
# MAli-v1.1,BALIS-2,BB20032,0.285,3140
# MAli-v1.1,BALIS-2,BB20033,0.28,1749
# MAli-v1.1,BALIS-2,BB20034,0.0306,4541
# MAli-v1.1,BALIS-2,BB20035,0.00857,4029
# MAli-v1.1,BALIS-2,BB20036,0.063,2786
# MAli-v1.1,BALIS-2,BB20037,0.0,8081
# MAli-v1.1,BALIS-2,BB20038,0.124,1700
# MAli-v1.1,BALIS-2,BB20039,0.0291,4326
# MAli-v1.1,BALIS-2,BB20040,0.0633,4622
# MAli-v1.1,BALIS-2,BB30002,0.0174,4367
# MAli-v1.1,BALIS-2,BB30003,0.0357,4952
# MAli-v1.1,BALIS-2,BB30005,0.104,4818
# MAli-v1.1,BALIS-2,BB30009,0.0,1441
# MAli-v1.1,BALIS-2,BB30010,0.135,5507
# MAli-v1.1,BALIS-2,BB30012,0.0792,4206
# MAli-v1.1,BALIS-2,BB30013,0.0,6350
# MAli-v1.1,BALIS-2,BB30020,0.0,3315
# MAli-v1.1,BALIS-2,BB30024,0.0267,4126
# MAli-v1.1,BALIS-2,BB30030,0.0058,4431
# MAli-v1.1,BALIS-2,BB40002,0.0952,2287
# MAli-v1.1,BALIS-2,BB40006,0.0414,4039
# MAli-v1.1,BALIS-2,BB40011,0.0381,3056
# MAli-v1.1,BALIS-2,BB40012,0.257,3483
# MAli-v1.1,BALIS-2,BB40013,0.176,3474
# MAli-v1.1,BALIS-2,BB40014,0.247,3199
# MAli-v1.1,BALIS-2,BB40017,0.256,2603
# MAli-v1.1,BALIS-2,BB40023,0.334,5107
# MAli-v1.1,BALIS-2,BB40030,0.116,3536
# MAli-v1.1,BALIS-2,BB40034,0.112,7172
# MAli-v1.1,BALIS-2,BB40035,0.522,3237
# MAli-v1.1,BALIS-2,BB40040,0.727,2722
# MAli-v1.1,BALIS-2,BB40042,0.0612,3587
# MAli-v1.1,BALIS-2,BB40043,0.0,4066
# MAli-v1.1,BALIS-2,BB40044,0.0107,2588
# MAli-v1.1,BALIS-2,BB40045,0.426,1656
# MAli-v1.1,BALIS-2,BB50002,0.00733,8451
# MAli-v1.1,BALIS-2,BB50003,0.0,5434
# MAli-v1.1,BALIS-2,BB50006,0.00898,7669
# MAli-v1.1,BALIS-2,BB50009,0.044,4714
# MAli-v1.1,BALIS-2,BB50010,0.197,4261
# MAli-v1.1,BALIS-2,BB50013,0.412,2949
# MAli-v1.1,BALIS-2,BB50015,0.0,5805
# Results written to: results/MAli-v1.1/sbench_MAli-v1.1_on_BALIS-2_30_iterations.csv
# MAli-v1.1,BALIS-2,BB11001,0.667,1139
# MAli-v1.1,BALIS-2,BB11002,0.0,1806
# MAli-v1.1,BALIS-2,BB11003,0.031,3358
# MAli-v1.1,BALIS-2,BB11006,0.0536,2449
# MAli-v1.1,BALIS-2,BB11007,0.0869,3398
# MAli-v1.1,BALIS-2,BB11010,0.0556,3270
# MAli-v1.1,BALIS-2,BB11012,0.167,2714
# MAli-v1.1,BALIS-2,BB11013,0.0414,1239
# MAli-v1.1,BALIS-2,BB11017,0.255,2114
# MAli-v1.1,BALIS-2,BB11020,0.0711,2138
# MAli-v1.1,BALIS-2,BB11023,0.0215,2921
# MAli-v1.1,BALIS-2,BB11024,0.0243,3115
# MAli-v1.1,BALIS-2,BB11026,0.0,5586
# MAli-v1.1,BALIS-2,BB11028,0.0311,2044
# MAli-v1.1,BALIS-2,BB11030,0.0127,3490
# MAli-v1.1,BALIS-2,BB11032,0.00517,2951
# MAli-v1.1,BALIS-2,BB11034,0.00321,4905
# MAli-v1.1,BALIS-2,BB11035,0.116,1414
# MAli-v1.1,BALIS-2,BB11036,0.0404,3261
# MAli-v1.1,BALIS-2,BB12001,0.301,3160
# MAli-v1.1,BALIS-2,BB12003,0.937,963
# MAli-v1.1,BALIS-2,BB12006,0.644,1954
# MAli-v1.1,BALIS-2,BB12008,0.501,2853
# MAli-v1.1,BALIS-2,BB12015,0.117,1747
# MAli-v1.1,BALIS-2,BB12017,0.164,3351
# MAli-v1.1,BALIS-2,BB12020,0.546,1358
# MAli-v1.1,BALIS-2,BB12022,0.327,1476
# MAli-v1.1,BALIS-2,BB12025,0.688,1769
# MAli-v1.1,BALIS-2,BB12032,0.485,1017
# MAli-v1.1,BALIS-2,BB12033,0.277,3107
# MAli-v1.1,BALIS-2,BB12035,0.236,2272
# MAli-v1.1,BALIS-2,BB12036,0.259,2121
# MAli-v1.1,BALIS-2,BB12038,0.629,2039
# MAli-v1.1,BALIS-2,BB12041,0.387,1291
# MAli-v1.1,BALIS-2,BB12043,0.182,2259
# MAli-v1.1,BALIS-2,BB20002,0.0,1670
# MAli-v1.1,BALIS-2,BB20005,0.0143,3490
# MAli-v1.1,BALIS-2,BB20010,0.191,4053
# MAli-v1.1,BALIS-2,BB20016,0.0667,2630
# MAli-v1.1,BALIS-2,BB20018,0.238,2433
# MAli-v1.1,BALIS-2,BB20019,0.0,4556
# MAli-v1.1,BALIS-2,BB20020,0.202,2177
# MAli-v1.1,BALIS-2,BB20025,0.0,2908
# MAli-v1.1,BALIS-2,BB20026,0.0,4908
# MAli-v1.1,BALIS-2,BB20028,0.0167,3669
# MAli-v1.1,BALIS-2,BB20029,0.0,1222
# MAli-v1.1,BALIS-2,BB20030,0.0729,1200
# MAli-v1.1,BALIS-2,BB20031,0.0,2884
# MAli-v1.1,BALIS-2,BB20032,0.218,1299
# MAli-v1.1,BALIS-2,BB20033,0.217,1312
# MAli-v1.1,BALIS-2,BB20034,0.0145,2895
# MAli-v1.1,BALIS-2,BB20035,0.00857,2699
# MAli-v1.1,BALIS-2,BB20036,0.0556,1995
# MAli-v1.1,BALIS-2,BB20037,0.0,4917
# MAli-v1.1,BALIS-2,BB20038,0.124,1361
# MAli-v1.1,BALIS-2,BB20039,0.00874,3033
# MAli-v1.1,BALIS-2,BB20040,0.0,3336
# MAli-v1.1,BALIS-2,BB30002,0.0504,3126
# MAli-v1.1,BALIS-2,BB30003,0.0151,3491
# MAli-v1.1,BALIS-2,BB30005,0.0859,3480
# MAli-v1.1,BALIS-2,BB30009,0.0,1199
# MAli-v1.1,BALIS-2,BB30010,0.135,3921
# MAli-v1.1,BALIS-2,BB30012,0.0413,3042
# MAli-v1.1,BALIS-2,BB30013,0.00435,4377
# MAli-v1.1,BALIS-2,BB30020,0.0357,2600
# MAli-v1.1,BALIS-2,BB30024,0.00571,2975
# MAli-v1.1,BALIS-2,BB30030,0.00207,3210
# MAli-v1.1,BALIS-2,BB40002,0.0501,1740
# MAli-v1.1,BALIS-2,BB40006,0.0355,2841
# MAli-v1.1,BALIS-2,BB40011,0.0,2229
# MAli-v1.1,BALIS-2,BB40012,0.0957,2618
# MAli-v1.1,BALIS-2,BB40013,0.176,2658
# MAli-v1.1,BALIS-2,BB40014,0.213,2342
# MAli-v1.1,BALIS-2,BB40017,0.107,1996
# MAli-v1.1,BALIS-2,BB40023,0.244,3625
# MAli-v1.1,BALIS-2,BB40030,0.0967,2687
# MAli-v1.1,BALIS-2,BB40034,0.112,4939
# MAli-v1.1,BALIS-2,BB40035,0.522,2274
# MAli-v1.1,BALIS-2,BB40040,0.668,1992
# MAli-v1.1,BALIS-2,BB40042,0.0492,2640
# MAli-v1.1,BALIS-2,BB40043,0.0,2783
# MAli-v1.1,BALIS-2,BB40044,0.0107,1946
# MAli-v1.1,BALIS-2,BB40045,0.405,1307
# MAli-v1.1,BALIS-2,BB50002,0.00305,5895
# MAli-v1.1,BALIS-2,BB50003,0.0,3794
# MAli-v1.1,BALIS-2,BB50006,0.00696,5347
# MAli-v1.1,BALIS-2,BB50009,0.044,3407
# MAli-v1.1,BALIS-2,BB50010,0.0943,3025
# MAli-v1.1,BALIS-2,BB50013,0.189,2238
# MAli-v1.1,BALIS-2,BB50015,0.0,4220
# Results written to: results/MAli-v1.1/sbench_MAli-v1.1_on_BALIS-2_20_iterations.csv
# MAli-v1.1,BALIS-2,BB11001,0.401,940
# MAli-v1.1,BALIS-2,BB11002,0.0,1222
# MAli-v1.1,BALIS-2,BB11003,0.00675,2022
# MAli-v1.1,BALIS-2,BB11006,0.0283,1506
# MAli-v1.1,BALIS-2,BB11007,0.0606,2084
# MAli-v1.1,BALIS-2,BB11010,0.047,1942
# MAli-v1.1,BALIS-2,BB11012,0.0319,1691
# MAli-v1.1,BALIS-2,BB11013,0.0,940
# MAli-v1.1,BALIS-2,BB11017,0.127,1363
# MAli-v1.1,BALIS-2,BB11020,0.0452,1346
# MAli-v1.1,BALIS-2,BB11023,0.0273,1744
# MAli-v1.1,BALIS-2,BB11024,0.0243,1882
# MAli-v1.1,BALIS-2,BB11026,0.0,3103
# MAli-v1.1,BALIS-2,BB11028,0.0333,1362
# MAli-v1.1,BALIS-2,BB11030,0.0153,2161
# MAli-v1.1,BALIS-2,BB11032,0.00376,1854
# MAli-v1.1,BALIS-2,BB11034,0.00321,2856
# MAli-v1.1,BALIS-2,BB11035,0.0838,1051
# MAli-v1.1,BALIS-2,BB11036,0.0252,1979
# MAli-v1.1,BALIS-2,BB12001,0.279,1885
# MAli-v1.1,BALIS-2,BB12003,0.676,725
# MAli-v1.1,BALIS-2,BB12006,0.351,1325
# MAli-v1.1,BALIS-2,BB12008,0.379,1812
# MAli-v1.1,BALIS-2,BB12015,0.00833,1162
# MAli-v1.1,BALIS-2,BB12017,0.132,2046
# MAli-v1.1,BALIS-2,BB12020,0.459,959
# MAli-v1.1,BALIS-2,BB12022,0.176,1029
# MAli-v1.1,BALIS-2,BB12025,0.422,1191
# MAli-v1.1,BALIS-2,BB12032,0.485,800
# MAli-v1.1,BALIS-2,BB12033,0.327,1767
# MAli-v1.1,BALIS-2,BB12035,0.163,1485
# MAli-v1.1,BALIS-2,BB12036,0.114,1410
# MAli-v1.1,BALIS-2,BB12038,0.469,1230
# MAli-v1.1,BALIS-2,BB12041,0.178,942
# MAli-v1.1,BALIS-2,BB12043,0.187,1487
# MAli-v1.1,BALIS-2,BB20002,0.0645,1129
# MAli-v1.1,BALIS-2,BB20005,0.00702,2069
# MAli-v1.1,BALIS-2,BB20010,0.0203,2273
# MAli-v1.1,BALIS-2,BB20016,0.0667,1639
# MAli-v1.1,BALIS-2,BB20018,0.108,1716
# MAli-v1.1,BALIS-2,BB20019,0.0,2589
# MAli-v1.1,BALIS-2,BB20020,0.143,1394
# MAli-v1.1,BALIS-2,BB20025,0.0,1739
# MAli-v1.1,BALIS-2,BB20026,0.0,2690
# MAli-v1.1,BALIS-2,BB20028,0.028,2089
# MAli-v1.1,BALIS-2,BB20029,0.0,921
# MAli-v1.1,BALIS-2,BB20030,0.0365,888
# MAli-v1.1,BALIS-2,BB20031,0.0,1714
# MAli-v1.1,BALIS-2,BB20032,0.17,929
# MAli-v1.1,BALIS-2,BB20033,0.142,971
# MAli-v1.1,BALIS-2,BB20034,0.00978,1753
# MAli-v1.1,BALIS-2,BB20035,0.00667,1714
# MAli-v1.1,BALIS-2,BB20036,0.0,1353
# MAli-v1.1,BALIS-2,BB20037,0.0,2856
# MAli-v1.1,BALIS-2,BB20038,0.0286,971
# MAli-v1.1,BALIS-2,BB20039,0.00874,1993
# MAli-v1.1,BALIS-2,BB20040,0.0,1953
# MAli-v1.1,BALIS-2,BB30002,0.0368,1852
# MAli-v1.1,BALIS-2,BB30003,0.0175,2131
# MAli-v1.1,BALIS-2,BB30005,0.0658,2160
# MAli-v1.1,BALIS-2,BB30009,0.0,873
# MAli-v1.1,BALIS-2,BB30010,0.0513,2354
# MAli-v1.1,BALIS-2,BB30012,0.0165,2015
# MAli-v1.1,BALIS-2,BB30013,0.00522,2786
# MAli-v1.1,BALIS-2,BB30020,0.0,1670
# MAli-v1.1,BALIS-2,BB30024,0.00857,2064
# MAli-v1.1,BALIS-2,BB30030,0.00455,2192
# MAli-v1.1,BALIS-2,BB40002,0.0,1319
# MAli-v1.1,BALIS-2,BB40006,0.0207,1992
# MAli-v1.1,BALIS-2,BB40011,0.00696,1541
# MAli-v1.1,BALIS-2,BB40012,0.00591,1538
# MAli-v1.1,BALIS-2,BB40013,0.0471,1641
# MAli-v1.1,BALIS-2,BB40014,0.154,1471
# MAli-v1.1,BALIS-2,BB40017,0.103,1295
# MAli-v1.1,BALIS-2,BB40023,0.189,2068
# MAli-v1.1,BALIS-2,BB40030,0.0488,1603
# MAli-v1.1,BALIS-2,BB40034,0.112,2737
# MAli-v1.1,BALIS-2,BB40035,0.298,1488
# MAli-v1.1,BALIS-2,BB40040,0.48,1335
# MAli-v1.1,BALIS-2,BB40042,0.0225,1627
# MAli-v1.1,BALIS-2,BB40043,0.0,1680
# MAli-v1.1,BALIS-2,BB40044,0.0373,1335
# MAli-v1.1,BALIS-2,BB40045,0.195,984
# MAli-v1.1,BALIS-2,BB50002,0.00153,3732
# MAli-v1.1,BALIS-2,BB50003,0.0,2290
# MAli-v1.1,BALIS-2,BB50006,0.00224,3160
# MAli-v1.1,BALIS-2,BB50009,0.02,2226
# MAli-v1.1,BALIS-2,BB50010,0.0,2005
# MAli-v1.1,BALIS-2,BB50013,0.121,1490
# MAli-v1.1,BALIS-2,BB50015,0.00554,2523
# Results written to: results/MAli-v1.1/sbench_MAli-v1.1_on_BALIS-2_10_iterations.csv
# MAli-v1.1,BALIS-2,BB11001,0.0351,145
# MAli-v1.1,BALIS-2,BB11002,0.021,244
# MAli-v1.1,BALIS-2,BB11003,0.00877,678
# MAli-v1.1,BALIS-2,BB11006,0.0402,360
# MAli-v1.1,BALIS-2,BB11007,0.0632,658
# MAli-v1.1,BALIS-2,BB11010,0.0,622
# MAli-v1.1,BALIS-2,BB11012,0.0252,541
# MAli-v1.1,BALIS-2,BB11013,0.0138,168
# MAli-v1.1,BALIS-2,BB11017,0.096,342
# MAli-v1.1,BALIS-2,BB11020,0.0356,346
# MAli-v1.1,BALIS-2,BB11023,0.0482,591
# MAli-v1.1,BALIS-2,BB11024,0.00647,610
# MAli-v1.1,BALIS-2,BB11026,0.00366,879
# MAli-v1.1,BALIS-2,BB11028,0.01,299
# MAli-v1.1,BALIS-2,BB11030,0.0215,580
# MAli-v1.1,BALIS-2,BB11032,0.015,583
# MAli-v1.1,BALIS-2,BB11034,0.0154,855
# MAli-v1.1,BALIS-2,BB11035,0.0676,194
# MAli-v1.1,BALIS-2,BB11036,0.045,668
# MAli-v1.1,BALIS-2,BB12001,0.0492,618
# MAli-v1.1,BALIS-2,BB12003,0.432,136
# MAli-v1.1,BALIS-2,BB12006,0.108,349
# MAli-v1.1,BALIS-2,BB12008,0.181,433
# MAli-v1.1,BALIS-2,BB12015,0.0611,231
# MAli-v1.1,BALIS-2,BB12017,0.0373,565
# MAli-v1.1,BALIS-2,BB12020,0.145,174
# MAli-v1.1,BALIS-2,BB12022,0.0523,189
# MAli-v1.1,BALIS-2,BB12025,0.38,231
# MAli-v1.1,BALIS-2,BB12032,0.304,128
# MAli-v1.1,BALIS-2,BB12033,0.11,570
# MAli-v1.1,BALIS-2,BB12035,0.12,358
# MAli-v1.1,BALIS-2,BB12036,0.0838,281
# MAli-v1.1,BALIS-2,BB12038,0.223,290
# MAli-v1.1,BALIS-2,BB12041,0.102,156
# MAli-v1.1,BALIS-2,BB12043,0.136,349
# MAli-v1.1,BALIS-2,BB20002,0.0,220
# MAli-v1.1,BALIS-2,BB20005,0.0243,645
# MAli-v1.1,BALIS-2,BB20010,0.0486,663
# MAli-v1.1,BALIS-2,BB20016,0.0111,507
# MAli-v1.1,BALIS-2,BB20018,0.0486,471
# MAli-v1.1,BALIS-2,BB20019,0.00133,698
# MAli-v1.1,BALIS-2,BB20020,0.0841,329
# MAli-v1.1,BALIS-2,BB20025,0.0423,562
# MAli-v1.1,BALIS-2,BB20026,0.0066,717
# MAli-v1.1,BALIS-2,BB20028,0.0113,656
# MAli-v1.1,BALIS-2,BB20029,0.00575,153
# MAli-v1.1,BALIS-2,BB20030,0.0885,154
# MAli-v1.1,BALIS-2,BB20031,0.00317,554
# MAli-v1.1,BALIS-2,BB20032,0.118,159
# MAli-v1.1,BALIS-2,BB20033,0.102,166
# MAli-v1.1,BALIS-2,BB20034,0.017,554
# MAli-v1.1,BALIS-2,BB20035,0.02,544
# MAli-v1.1,BALIS-2,BB20036,0.0037,293
# MAli-v1.1,BALIS-2,BB20037,0.0125,862
# MAli-v1.1,BALIS-2,BB20038,0.0667,174
# MAli-v1.1,BALIS-2,BB20039,0.0214,595
# MAli-v1.1,BALIS-2,BB20040,0.0,587
# MAli-v1.1,BALIS-2,BB30002,0.0368,601
# MAli-v1.1,BALIS-2,BB30003,0.0135,665
# MAli-v1.1,BALIS-2,BB30005,0.0656,658
# MAli-v1.1,BALIS-2,BB30009,0.0,159
# MAli-v1.1,BALIS-2,BB30010,0.0216,688
# MAli-v1.1,BALIS-2,BB30012,0.0182,573
# MAli-v1.1,BALIS-2,BB30013,0.00087,753
# MAli-v1.1,BALIS-2,BB30020,0.0167,499
# MAli-v1.1,BALIS-2,BB30024,0.0133,575
# MAli-v1.1,BALIS-2,BB30030,0.0166,638
# MAli-v1.1,BALIS-2,BB40002,0.00752,234
# MAli-v1.1,BALIS-2,BB40006,0.0402,555
# MAli-v1.1,BALIS-2,BB40011,0.0283,378
# MAli-v1.1,BALIS-2,BB40012,0.013,487
# MAli-v1.1,BALIS-2,BB40013,0.0229,511
# MAli-v1.1,BALIS-2,BB40014,0.139,384
# MAli-v1.1,BALIS-2,BB40017,0.0312,253
# MAli-v1.1,BALIS-2,BB40023,0.086,668
# MAli-v1.1,BALIS-2,BB40030,0.0244,472
# MAli-v1.1,BALIS-2,BB40034,0.00658,793
# MAli-v1.1,BALIS-2,BB40035,0.175,382
# MAli-v1.1,BALIS-2,BB40040,0.278,306
# MAli-v1.1,BALIS-2,BB40042,0.0354,487
# MAli-v1.1,BALIS-2,BB40043,0.0175,607
# MAli-v1.1,BALIS-2,BB40044,0.0187,270
# MAli-v1.1,BALIS-2,BB40045,0.103,171
# MAli-v1.1,BALIS-2,BB50002,0.0128,1053
# MAli-v1.1,BALIS-2,BB50003,0.0462,638
# MAli-v1.1,BALIS-2,BB50006,0.00516,865
# MAli-v1.1,BALIS-2,BB50009,0.012,631
# MAli-v1.1,BALIS-2,BB50010,0.0,579
# MAli-v1.1,BALIS-2,BB50013,0.021,322
# MAli-v1.1,BALIS-2,BB50015,0.00677,714
# Results written to: results/MAli-v1.1/sbench_MAli-v1.1_on_BALIS-2_1_iterations.csv
