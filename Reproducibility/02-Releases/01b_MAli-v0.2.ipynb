# %% [markdown]
# ## Release Testing: MAli-v0.2 on BALIS-2

# %% [markdown]
# #### Imports

# %%
import os
import shutil
import subprocess
import time
import pandas as pd

# %%
from wrapped_scorer import WrappedScorer

# %% [markdown]
# #### MAli

# %%
SEED = 9032025

# %%
ALIGNER_NAME = "MAli-v0.2"
ALIGNER_PATH = f"aligners/{ALIGNER_NAME}/MAli.exe"
OUTPUT_FOLDER = f"aligners/{ALIGNER_NAME}/output"

# %%
# creating empty output folder
if os.path.exists(OUTPUT_FOLDER):
    shutil.rmtree(OUTPUT_FOLDER)
os.makedirs(OUTPUT_FOLDER)

# %%
RESULTS_FILE_DIRECTORY = f"results/{ALIGNER_NAME}"

# %%
# creating empty output folder
if os.path.exists(RESULTS_FILE_DIRECTORY):
    shutil.rmtree(RESULTS_FILE_DIRECTORY)
os.makedirs(RESULTS_FILE_DIRECTORY)

# %% [markdown]
# #### BALIS-2

# %%
DATASET_NAME = "BALIS-2"
DATASET_FOLDER = f"datasets/{DATASET_NAME}"
INPUT_FOLDER = f"{DATASET_FOLDER}/in"
REFERENCES_FOLDER = f"{DATASET_FOLDER}/ref"

# %%
# checking that testcases have been found
testcases = os.listdir(INPUT_FOLDER)
print(testcases[:10])
# Out:
# ['BB11001', 'BB11002', 'BB11003', 'BB11006', 'BB11007', 'BB11010', 'BB11012', 'BB11013', 'BB11017', 'BB11020']

# %% [markdown]
# #### QScore

# %%
SCORER_PATH = "scorers/QScore/qscore.exe"

# %%
scorer = WrappedScorer(SCORER_PATH)

# %% [markdown]
# #### Performing Alignment

# %%
def perform_alignment_and_record_time(filename):

    input_path = f"{INPUT_FOLDER}/{filename}"
    output_path = f"{OUTPUT_FOLDER}/{filename}"
    command = f"{ALIGNER_PATH} -input {input_path} -output {output_path} -seed {SEED} -iterations {iterations}"

    start_time = time.perf_counter()
    
    subprocess.run(command)

    end_time = time.perf_counter()
    
    time_in_milliseconds = (end_time - start_time) * 1000
    time_in_milliseconds = round(time_in_milliseconds, 0)

    return int(time_in_milliseconds)

# %%
def score_quality_of_produced_alignment(filename):

    test_path = f"{OUTPUT_FOLDER}/{filename}"
    reference_path = f"{REFERENCES_FOLDER}/{filename}"
    score = scorer.score_testcase(test_path, reference_path)

    return score

# %%
def record_performance_on_testcase(filename):

    time_taken = perform_alignment_and_record_time(testcase)
    score = score_quality_of_produced_alignment(testcase)


    return f"{ALIGNER_NAME},{DATASET_NAME},{filename},{score},{time_taken}"

# %%
def write_records_to_csv(records, filename):

    RESULTS_FILEPATH = f"{RESULTS_FILE_DIRECTORY}/{filename}"

    with open(RESULTS_FILEPATH, "w") as file:
        for record in RECORDS:
            file.write(record)
            file.write("\n")

    print(f"Results written to: {RESULTS_FILEPATH}")

# %%
HEADER = "aligner,dataset,testcase,Q_score,time_elapsed_ms"

# %%
for iterations in [2000, 1000, 500, 200, 100, 1]:
    RECORDS = []
    RECORDS.append(HEADER)

    RESULTS_FILENAME = f"sbench_{ALIGNER_NAME}_on_{DATASET_NAME}_{iterations}_iterations.csv"
    RESULTS_FILEPATH = f"results/{RESULTS_FILENAME}"
    for testcase in testcases:
        record = record_performance_on_testcase(testcase)
# Results written to: results/MAli-v0.2/sbench_MAli-v0.2_on_BALIS-2_500_iterations.csv
# MAli-v0.2,BALIS-2,BB11001,0.0965,439
# MAli-v0.2,BALIS-2,BB11002,0.021,708
# MAli-v0.2,BALIS-2,BB11003,0.0175,1212
# MAli-v0.2,BALIS-2,BB11006,0.0201,914
# MAli-v0.2,BALIS-2,BB11007,0.0561,1424
# MAli-v0.2,BALIS-2,BB11010,0.0256,1143
# MAli-v0.2,BALIS-2,BB11012,0.0471,945
# MAli-v0.2,BALIS-2,BB11013,0.0138,492
# MAli-v0.2,BALIS-2,BB11017,0.131,706
# MAli-v0.2,BALIS-2,BB11020,0.0463,816
# MAli-v0.2,BALIS-2,BB11023,0.0372,1159
# MAli-v0.2,BALIS-2,BB11024,0.0,1062
# MAli-v0.2,BALIS-2,BB11026,0.00366,3308
# MAli-v0.2,BALIS-2,BB11028,0.0311,784
# MAli-v0.2,BALIS-2,BB11030,0.0185,1568
# MAli-v0.2,BALIS-2,BB11032,0.0108,1251
# MAli-v0.2,BALIS-2,BB11034,0.0111,2606
# MAli-v0.2,BALIS-2,BB11035,0.0432,574
# MAli-v0.2,BALIS-2,BB11036,0.0268,1285
# MAli-v0.2,BALIS-2,BB12001,0.0109,1002
# MAli-v0.2,BALIS-2,BB12003,0.27,235
# MAli-v0.2,BALIS-2,BB12006,0.2,659
# MAli-v0.2,BALIS-2,BB12008,0.269,911
# MAli-v0.2,BALIS-2,BB12015,0.0278,615
# MAli-v0.2,BALIS-2,BB12017,0.0585,1094
# MAli-v0.2,BALIS-2,BB12020,0.157,514
# MAli-v0.2,BALIS-2,BB12022,0.0523,537
# MAli-v0.2,BALIS-2,BB12025,0.734,609
# MAli-v0.2,BALIS-2,BB12032,0.507,273
# MAli-v0.2,BALIS-2,BB12033,0.164,991
# MAli-v0.2,BALIS-2,BB12035,0.115,794
# MAli-v0.2,BALIS-2,BB12036,0.105,743
# MAli-v0.2,BALIS-2,BB12038,0.366,694
# MAli-v0.2,BALIS-2,BB12041,0.17,520
# MAli-v0.2,BALIS-2,BB12043,0.127,855
# MAli-v0.2,BALIS-2,BB20002,0.0,592
# MAli-v0.2,BALIS-2,BB20005,0.0196,1536
# MAli-v0.2,BALIS-2,BB20010,0.108,1302
# MAli-v0.2,BALIS-2,BB20016,0.0167,965
# MAli-v0.2,BALIS-2,BB20018,0.0435,918
# MAli-v0.2,BALIS-2,BB20019,0.0213,1716
# MAli-v0.2,BALIS-2,BB20020,0.0749,809
# MAli-v0.2,BALIS-2,BB20025,0.0,960
# MAli-v0.2,BALIS-2,BB20026,0.0033,1745
# MAli-v0.2,BALIS-2,BB20028,0.0122,1563
# MAli-v0.2,BALIS-2,BB20029,0.0172,486
# MAli-v0.2,BALIS-2,BB20030,0.0156,487
# MAli-v0.2,BALIS-2,BB20031,0.00635,1013
# MAli-v0.2,BALIS-2,BB20032,0.097,506
# MAli-v0.2,BALIS-2,BB20033,0.158,518
# MAli-v0.2,BALIS-2,BB20034,0.00893,1175
# MAli-v0.2,BALIS-2,BB20035,0.0171,999
# MAli-v0.2,BALIS-2,BB20036,0.0148,723
# MAli-v0.2,BALIS-2,BB20037,0.0179,2731
# MAli-v0.2,BALIS-2,BB20038,0.0476,507
# MAli-v0.2,BALIS-2,BB20039,0.00485,1158
# MAli-v0.2,BALIS-2,BB20040,0.0309,1111
# MAli-v0.2,BALIS-2,BB30002,0.0136,1064
# MAli-v0.2,BALIS-2,BB30003,0.025,1560
# MAli-v0.2,BALIS-2,BB30005,0.0854,1996
# MAli-v0.2,BALIS-2,BB30009,0.0123,446
# MAli-v0.2,BALIS-2,BB30010,0.0445,1277
# MAli-v0.2,BALIS-2,BB30012,0.033,1041
# MAli-v0.2,BALIS-2,BB30013,0.0157,1781
# MAli-v0.2,BALIS-2,BB30020,0.00714,1013
# MAli-v0.2,BALIS-2,BB30024,0.00762,1199
# MAli-v0.2,BALIS-2,BB30030,0.0232,1250
# MAli-v0.2,BALIS-2,BB40002,0.0251,684
# MAli-v0.2,BALIS-2,BB40006,0.0456,1070
# MAli-v0.2,BALIS-2,BB40011,0.0319,975
# MAli-v0.2,BALIS-2,BB40012,0.0366,877
# MAli-v0.2,BALIS-2,BB40013,0.0271,1066
# MAli-v0.2,BALIS-2,BB40014,0.245,751
# MAli-v0.2,BALIS-2,BB40017,0.0268,753
# MAli-v0.2,BALIS-2,BB40023,0.0944,1365
# MAli-v0.2,BALIS-2,BB40030,0.0382,924
# MAli-v0.2,BALIS-2,BB40034,0.0,2027
# MAli-v0.2,BALIS-2,BB40035,0.151,739
# MAli-v0.2,BALIS-2,BB40040,0.335,706
# MAli-v0.2,BALIS-2,BB40042,0.0294,1042
# MAli-v0.2,BALIS-2,BB40043,0.00125,1059
# MAli-v0.2,BALIS-2,BB40044,0.008,728
# MAli-v0.2,BALIS-2,BB40045,0.197,519
# MAli-v0.2,BALIS-2,BB50002,0.00946,8139
# MAli-v0.2,BALIS-2,BB50003,0.0957,1236
# MAli-v0.2,BALIS-2,BB50006,0.00359,3409
# MAli-v0.2,BALIS-2,BB50009,0.004,1250
# MAli-v0.2,BALIS-2,BB50010,0.0,1065
# MAli-v0.2,BALIS-2,BB50013,0.0367,707
# MAli-v0.2,BALIS-2,BB50015,0.00739,2310
# Results written to: results/MAli-v0.2/sbench_MAli-v0.2_on_BALIS-2_200_iterations.csv
# MAli-v0.2,BALIS-2,BB11001,0.105,194
# MAli-v0.2,BALIS-2,BB11002,0.0231,564
# MAli-v0.2,BALIS-2,BB11003,0.0142,784
# MAli-v0.2,BALIS-2,BB11006,0.0186,668
# MAli-v0.2,BALIS-2,BB11007,0.0491,931
# MAli-v0.2,BALIS-2,BB11010,0.0256,767
# MAli-v0.2,BALIS-2,BB11012,0.0438,657
# MAli-v0.2,BALIS-2,BB11013,0.0172,222
# MAli-v0.2,BALIS-2,BB11017,0.108,545
# MAli-v0.2,BALIS-2,BB11020,0.0474,624
# MAli-v0.2,BALIS-2,BB11023,0.0366,807
# MAli-v0.2,BALIS-2,BB11024,0.0,734
# MAli-v0.2,BALIS-2,BB11026,0.00366,1859
# MAli-v0.2,BALIS-2,BB11028,0.03,608
# MAli-v0.2,BALIS-2,BB11030,0.0194,1007
# MAli-v0.2,BALIS-2,BB11032,0.0122,827
# MAli-v0.2,BALIS-2,BB11034,0.0118,1610
# MAli-v0.2,BALIS-2,BB11035,0.0514,374
# MAli-v0.2,BALIS-2,BB11036,0.0276,890
# MAli-v0.2,BALIS-2,BB12001,0.0109,712
# MAli-v0.2,BALIS-2,BB12003,0.27,153
# MAli-v0.2,BALIS-2,BB12006,0.171,534
# MAli-v0.2,BALIS-2,BB12008,0.237,656
# MAli-v0.2,BALIS-2,BB12015,0.0278,499
# MAli-v0.2,BALIS-2,BB12017,0.0566,754
# MAli-v0.2,BALIS-2,BB12020,0.145,283
# MAli-v0.2,BALIS-2,BB12022,0.0523,355
# MAli-v0.2,BALIS-2,BB12025,0.677,491
# MAli-v0.2,BALIS-2,BB12032,0.478,160
# MAli-v0.2,BALIS-2,BB12033,0.104,702
# MAli-v0.2,BALIS-2,BB12035,0.0914,633
# MAli-v0.2,BALIS-2,BB12036,0.101,549
# MAli-v0.2,BALIS-2,BB12038,0.283,537
# MAli-v0.2,BALIS-2,BB12041,0.124,251
# MAli-v0.2,BALIS-2,BB12043,0.124,646
# MAli-v0.2,BALIS-2,BB20002,0.0,485
# MAli-v0.2,BALIS-2,BB20005,0.022,970
# MAli-v0.2,BALIS-2,BB20010,0.0915,846
# MAli-v0.2,BALIS-2,BB20016,0.00714,689
# MAli-v0.2,BALIS-2,BB20018,0.0444,658
# MAli-v0.2,BALIS-2,BB20019,0.02,1074
# MAli-v0.2,BALIS-2,BB20020,0.0498,619
# MAli-v0.2,BALIS-2,BB20025,0.0,683
# MAli-v0.2,BALIS-2,BB20026,0.00165,1073
# MAli-v0.2,BALIS-2,BB20028,0.00869,988
# MAli-v0.2,BALIS-2,BB20029,0.0172,213
# MAli-v0.2,BALIS-2,BB20030,0.026,212
# MAli-v0.2,BALIS-2,BB20031,0.00476,696
# MAli-v0.2,BALIS-2,BB20032,0.0606,235
# MAli-v0.2,BALIS-2,BB20033,0.133,285
# MAli-v0.2,BALIS-2,BB20034,0.00935,798
# MAli-v0.2,BALIS-2,BB20035,0.0171,690
# MAli-v0.2,BALIS-2,BB20036,0.0111,572
# MAli-v0.2,BALIS-2,BB20037,0.0226,1654
# MAli-v0.2,BALIS-2,BB20038,0.0381,272
# MAli-v0.2,BALIS-2,BB20039,0.00485,771
# MAli-v0.2,BALIS-2,BB20040,0.0324,749
# MAli-v0.2,BALIS-2,BB30002,0.00904,726
# MAli-v0.2,BALIS-2,BB30003,0.0183,1005
# MAli-v0.2,BALIS-2,BB30005,0.0781,1009
# MAli-v0.2,BALIS-2,BB30009,0.0123,203
# MAli-v0.2,BALIS-2,BB30010,0.0364,870
# MAli-v0.2,BALIS-2,BB30012,0.00825,731
# MAli-v0.2,BALIS-2,BB30013,0.0113,1074
# MAli-v0.2,BALIS-2,BB30020,0.00952,682
# MAli-v0.2,BALIS-2,BB30024,0.00762,809
# MAli-v0.2,BALIS-2,BB30030,0.0228,817
# MAli-v0.2,BALIS-2,BB40002,0.0201,534
# MAli-v0.2,BALIS-2,BB40006,0.0432,768
# MAli-v0.2,BALIS-2,BB40011,0.0291,722
# MAli-v0.2,BALIS-2,BB40012,0.0366,645
# MAli-v0.2,BALIS-2,BB40013,0.0243,742
# MAli-v0.2,BALIS-2,BB40014,0.224,574
# MAli-v0.2,BALIS-2,BB40017,0.0208,580
# MAli-v0.2,BALIS-2,BB40023,0.0883,869
# MAli-v0.2,BALIS-2,BB40030,0.035,678
# MAli-v0.2,BALIS-2,BB40034,0.0,1214
# MAli-v0.2,BALIS-2,BB40035,0.124,570
# MAli-v0.2,BALIS-2,BB40040,0.258,536
# MAli-v0.2,BALIS-2,BB40042,0.0315,712
# MAli-v0.2,BALIS-2,BB40043,0.00375,742
# MAli-v0.2,BALIS-2,BB40044,0.008,566
# MAli-v0.2,BALIS-2,BB40045,0.147,242
# MAli-v0.2,BALIS-2,BB50002,0.00824,4362
# MAli-v0.2,BALIS-2,BB50003,0.0495,824
# MAli-v0.2,BALIS-2,BB50006,0.00404,1954
# MAli-v0.2,BALIS-2,BB50009,0.004,815
# MAli-v0.2,BALIS-2,BB50010,0.0,737
# MAli-v0.2,BALIS-2,BB50013,0.0262,542
# MAli-v0.2,BALIS-2,BB50015,0.00677,1296
# Results written to: results/MAli-v0.2/sbench_MAli-v0.2_on_BALIS-2_100_iterations.csv
# MAli-v0.2,BALIS-2,BB11001,0.0497,59
# MAli-v0.2,BALIS-2,BB11002,0.0168,70
# MAli-v0.2,BALIS-2,BB11003,0.0115,90
# MAli-v0.2,BALIS-2,BB11006,0.00595,77
# MAli-v0.2,BALIS-2,BB11007,0.0575,102
# MAli-v0.2,BALIS-2,BB11010,0.0,87
# MAli-v0.2,BALIS-2,BB11012,0.0219,80
# MAli-v0.2,BALIS-2,BB11013,0.0103,61
# MAli-v0.2,BALIS-2,BB11017,0.0574,72
# MAli-v0.2,BALIS-2,BB11020,0.033,72
# MAli-v0.2,BALIS-2,BB11023,0.0215,92
# MAli-v0.2,BALIS-2,BB11024,0.00971,84
# MAli-v0.2,BALIS-2,BB11026,0.0,163
# MAli-v0.2,BALIS-2,BB11028,0.0222,73
# MAli-v0.2,BALIS-2,BB11030,0.0172,110
# MAli-v0.2,BALIS-2,BB11032,0.023,96
# MAli-v0.2,BALIS-2,BB11034,0.00607,170
# MAli-v0.2,BALIS-2,BB11035,0.0297,65
# MAli-v0.2,BALIS-2,BB11036,0.0194,98
# MAli-v0.2,BALIS-2,BB12001,0.0123,79
# MAli-v0.2,BALIS-2,BB12003,0.216,58
# MAli-v0.2,BALIS-2,BB12006,0.11,67
# MAli-v0.2,BALIS-2,BB12008,0.105,80
# MAli-v0.2,BALIS-2,BB12015,0.0278,67
# MAli-v0.2,BALIS-2,BB12017,0.0243,86
# MAli-v0.2,BALIS-2,BB12020,0.15,61
# MAli-v0.2,BALIS-2,BB12022,0.0327,62
# MAli-v0.2,BALIS-2,BB12025,0.224,65
# MAli-v0.2,BALIS-2,BB12032,0.259,64
# MAli-v0.2,BALIS-2,BB12033,0.0828,83
# MAli-v0.2,BALIS-2,BB12035,0.0819,73
# MAli-v0.2,BALIS-2,BB12036,0.0376,70
# MAli-v0.2,BALIS-2,BB12038,0.14,69
# MAli-v0.2,BALIS-2,BB12041,0.0804,61
# MAli-v0.2,BALIS-2,BB12043,0.0923,76
# MAli-v0.2,BALIS-2,BB20002,0.0,64
# MAli-v0.2,BALIS-2,BB20005,0.0225,109
# MAli-v0.2,BALIS-2,BB20010,0.0475,92
# MAli-v0.2,BALIS-2,BB20016,0.0175,82
# MAli-v0.2,BALIS-2,BB20018,0.0278,77
# MAli-v0.2,BALIS-2,BB20019,0.0133,115
# MAli-v0.2,BALIS-2,BB20020,0.044,73
# MAli-v0.2,BALIS-2,BB20025,0.0,78
# MAli-v0.2,BALIS-2,BB20026,0.0,110
# MAli-v0.2,BALIS-2,BB20028,0.0106,112
# MAli-v0.2,BALIS-2,BB20029,0.023,59
# MAli-v0.2,BALIS-2,BB20030,0.0312,60
# MAli-v0.2,BALIS-2,BB20031,0.0111,83
# MAli-v0.2,BALIS-2,BB20032,0.0364,61
# MAli-v0.2,BALIS-2,BB20033,0.13,61
# MAli-v0.2,BALIS-2,BB20034,0.00935,92
# MAli-v0.2,BALIS-2,BB20035,0.0143,81
# MAli-v0.2,BALIS-2,BB20036,0.0037,70
# MAli-v0.2,BALIS-2,BB20037,0.0179,163
# MAli-v0.2,BALIS-2,BB20038,0.00952,62
# MAli-v0.2,BALIS-2,BB20039,0.00388,90
# MAli-v0.2,BALIS-2,BB20040,0.034,88
# MAli-v0.2,BALIS-2,BB30002,0.00646,85
# MAli-v0.2,BALIS-2,BB30003,0.0135,109
# MAli-v0.2,BALIS-2,BB30005,0.0714,106
# MAli-v0.2,BALIS-2,BB30009,0.0494,58
# MAli-v0.2,BALIS-2,BB30010,0.0216,93
# MAli-v0.2,BALIS-2,BB30012,0.0165,86
# MAli-v0.2,BALIS-2,BB30013,0.00957,118
# MAli-v0.2,BALIS-2,BB30020,0.00476,81
# MAli-v0.2,BALIS-2,BB30024,0.0162,90
# MAli-v0.2,BALIS-2,BB30030,0.0186,95
# MAli-v0.2,BALIS-2,BB40002,0.01,69
# MAli-v0.2,BALIS-2,BB40006,0.0444,86
# MAli-v0.2,BALIS-2,BB40011,0.0283,83
# MAli-v0.2,BALIS-2,BB40012,0.0177,76
# MAli-v0.2,BALIS-2,BB40013,0.0229,85
# MAli-v0.2,BALIS-2,BB40014,0.0591,71
# MAli-v0.2,BALIS-2,BB40017,0.0253,73
# MAli-v0.2,BALIS-2,BB40023,0.0721,95
# MAli-v0.2,BALIS-2,BB40030,0.0171,78
# MAli-v0.2,BALIS-2,BB40034,0.00219,126
# MAli-v0.2,BALIS-2,BB40035,0.0833,71
# MAli-v0.2,BALIS-2,BB40040,0.119,67
# MAli-v0.2,BALIS-2,BB40042,0.026,84
# MAli-v0.2,BALIS-2,BB40043,0.00125,83
# MAli-v0.2,BALIS-2,BB40044,0.0107,69
# MAli-v0.2,BALIS-2,BB40045,0.0842,62
# MAli-v0.2,BALIS-2,BB50002,0.00763,275
# MAli-v0.2,BALIS-2,BB50003,0.066,90
# MAli-v0.2,BALIS-2,BB50006,0.00292,202
# MAli-v0.2,BALIS-2,BB50009,0.00533,92
# MAli-v0.2,BALIS-2,BB50010,0.0,84
# MAli-v0.2,BALIS-2,BB50013,0.0236,68
# MAli-v0.2,BALIS-2,BB50015,0.00739,139
# Results written to: results/MAli-v0.2/sbench_MAli-v0.2_on_BALIS-2_1_iterations.csv
